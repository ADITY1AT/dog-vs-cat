# %%
# !pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.7.4.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: bleach in c:\users\kiit0001\anaconda3\lib\site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\kiit0001\anaconda3\lib\site-packages (from kaggle) (2024.7.4)
# Requirement already satisfied: charset-normalizer in c:\users\kiit0001\anaconda3\lib\site-packages (from kaggle) (2.0.4)
# Requirement already satisfied: idna in c:\users\kiit0001\anaconda3\lib\site-packages (from kaggle) (3.7)
# Requirement already satisfied: protobuf in c:\users\kiit0001\anaconda3\lib\site-packages (from kaggle) (3.20.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\kiit0001\anaconda3\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\kiit0001\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in c:\users\kiit0001\anaconda3\lib\site-packages (from kaggle) (2.32.2)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\kiit0001\anaconda3\lib\site-packages (from kaggle) (69.5.1)
# Requirement already satisfied: six>=1.10 in c:\users\kiit0001\anaconda3\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: text-unidecode in c:\users\kiit0001\anaconda3\lib\site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in c:\users\kiit0001\anaconda3\lib\site-packages (from kaggle) (4.66.4)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\kiit0001\anaconda3\lib\site-packages (from kaggle) (2.2.2)
# Requirement already satisfied: webencodings in c:\users\kiit0001\anaconda3\lib\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: packaging in c:\users\kiit0001\anaconda3\lib\site-packages (from bleach->kaggle) (23.2)
# Requirement already satisfied: colorama in c:\users\kiit0001\anaconda3\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Downloading kaggle-1.7.4.5-py3-none-any.whl (181 kB)
#    ---------------------------------------- 0.0/181.2 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/181.2 kB ? eta -:--:--
#    ------------- -------------------------- 61.4/181.2 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 174.1/181.2 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 181.2/181.2 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: kaggle
# Successfully installed kaggle-1.7.4.5

# %%
import os
import shutil

os.makedirs(os.path.expanduser("~/.kaggle"), exist_ok=True)
shutil.copy("kaggle.json", os.path.expanduser("~/.kaggle/kaggle.json"))
# chmod is not needed on Windows
# Out:
# 'C:\\Users\\KIIT0001/.kaggle/kaggle.json'

# %%
# Kaggle api 
# !kaggle competitions download -c dogs-vs-cats
# Out:
# 403 Client Error: Forbidden for url: https://www.kaggle.com/api/v1/competitions/data/download-all/dogs-vs-cats
